# %% [markdown]
# ### **Organize PSD Data**
#
# - [ ]  Ensure all power spectral data (PSD) is saved per **subject-session** in a consistent format:
#     - One file or object per subject-session
#     - Contains:
#         - EEG **channels**
#         - **Frequencies**
#         - Power per **epoch** or pre-averaged by condition
#     - Associated **metadata**:
#         - Subject ID
#         - Session ID
#         - Dataset name
#         - Cognitive **state label** (OT, MW)

# %%
from eeg_analyzer.dataset import Dataset
from utils.config import DATASETS

dataset_config = DATASETS['braboszcz2017']

dataset = Dataset(dataset_config)
dataset.load_subjects()

# %% [markdown]
# ### **Extract Alpha Power**
#
# - [ ]  For each subject-session
#     - Select **8–12 Hz** frequency band
#     - **Sum power across frequencies** per channel and epoch
# - [ ]  Result per epoch:
#
# ```python
# {
#     "subject_session": "001_1",
#     "subject_id": "001",
#     "session_id": "1",
#     "channel": "Pz",
#     "task": "SART",
#     "state": "MW",
#     "alpha_power": 3.45,
#     ...
# }
# ```

# %% [markdown]
# ### **Assign Numerical Condition Labels**
#
# For modeling the *ordinal direction* of alpha power:
#
# | State | Code |
# | --- | --- |
# | OT | 0 |
# | MW | 1 |
# | MED | 2 |
# - [ ]  For **Jin** and **Touryan**, you only use codes `0` and `1` (OT, MW)
# - [ ]  For **Braboszcz**, use codes `1` and `2` (MW, MED)

# %%
# Get all list of all epochs for all subject-session pairs as dict with these keys:
# 'subject_session', 'subject', 'session', 'channel', 'task', 'state', 'band_power'

epochs = dataset.to_long_band_power_list(freq_band=(8,12))  # Alpha band

estimated_length = dataset.estimate_long_band_power_length()

# %% [markdown]
# ### **Create Long-Form DataFrame per Dataset**
#
# For each dataset, prepare:
# | subject_session | subject_id | group | channel/ROI | state | alpha_power |
# | --- | --- | --- | --- | --- | --- |
# | 001_1 | 001 | NaN | Pz | 0 | 3.24 |
# | 001_1 | 001 | NaN | Pz | 1 | 3.88 |
# | 060_1 | 060 | vip | Pz | 1 | 5.12 |
# | 060_1 | 060 | vip | Pz | 2 | 6.00 |

# %%
# create a dataframe with the epochs
import pandas as pd
df_full = pd.DataFrame(epochs)
df_full.head()
# Out:
#   subject_session subject_id  session_id group  epoch_idx channel  \
# 0           025_1        025           1   ctr          0     Fp1
# 1           025_1        025           1   ctr          0     AF7
# 2           025_1        025           1   ctr          0     AF3
# 3           025_1        025           1   ctr          0      F1
# 4           025_1        025           1   ctr          0      F3
#
#   cortical_region hemisphere  task  state  band_power  is_bad
# 0      prefrontal       left  med2      0   23.498810   False
# 1      prefrontal       left  med2      0   19.521354   False
# 2      prefrontal       left  med2      0   27.098857   False
# 3         frontal       left  med2      0   37.130399   False
# 4         frontal       left  med2      0   29.661644   False

# %% [markdown]
# ## **Report the state balance**

# %%
state_counts = df_full['state'].value_counts()
state_counts = state_counts / state_counts.sum()
print(f"State balance: {state_counts.to_dict()}")
# Out:
# State balance: {0: 0.5088714761776096, 1: 0.49112852382239036}

# %% [markdown]
# ## **Make grouped DataFrames per channel**
#
# * [ ] Create a list of DataFrames for each its own channel.
# * [ ] Create a new column with the z-score within state.
# * [ ] Filter the data by removing all epochs with a z-score > 4.

# %%
# Create a list of dataframes for each channel (keep the channel column)
df_channels = []
for channel in df_full['channel'].unique():
    df_channel = df_full[df_full['channel'] == channel].reset_index(drop=True)
    df_channels.append(df_channel)

# create a new column with z-scores within each state
# def z_score_within_state(df):
#     grouped = df.groupby(['subject_session', 'state'])
#     df['z_score'] = grouped['band_power'].transform(lambda x: (x - x.mean()) / x.std())
#     return df

# # apply the z-score function to each channel dataframe
# df_channels_z = []
# for df_channel in df_channels:
#     df_channel_z = z_score_within_state(df_channel)
#     df_channels_z.append(df_channel_z)

# # Remove all rows where z_score > 3
# for i in range(len(df_channels_z)):
#     df_channels_z[i] = df_channels_z[i][df_channels_z[i]['z_score'] <= 3]

# print(df_channels_z[0].head())

# %% [markdown]
# ### **Fit Mixed Effects Model per Channel**
#
# Do this **separately for each dataset** and for each channel (or ROI):
#
# ### ✅ Model formula:
#
# ```python
# alpha_power ~ state + (state | subject_session)
# ```
#
# This:
#
# - Estimates the effect of `state` (e.g., OT → MW or MW → MED)
# - Models per-subject variability in both baseline (intercept) and sensitivity (slope)

# %%
# Fit mixed effects model per channel
import statsmodels.formula.api as smf
from statsmodels.tools.sm_exceptions import ConvergenceWarning

results_per_channel = {}

for df_channel in df_channels:
    channel_name = df_channel['channel'].iloc[0] if 'channel' in df_channel else None
    # Fit the mixed effects model: alpha_power ~ state + (state | subject_session)
    # Use 'band_power' as the dependent variable
    # 'state' as fixed effect, random intercept and slope for 'subject_session'
    model = smf.mixedlm(
        "band_power ~ state",
        df_channel,
        groups="subject_session",
        re_formula="~state"
    )
    result = model.fit(method="lbfgs")
    results_per_channel[channel_name] = result

# Print summary for all channels
for channel in results_per_channel:
    print(f"Results for channel: {channel}")
    print(results_per_channel[channel].summary())
# Out:
# Results for channel: Fp1
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  611.0866
# Min. group size:        150         Log-Likelihood:         -51598.7095
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     42.072    5.514 7.630 0.000 31.265 52.879
# state                          1.263    2.281 0.554 0.580 -3.207  5.734
# subject_session Var         1514.605   12.426
# subject_session x state Cov -114.638    3.698
# state Var                    248.861    2.127
# =======================================================================
#
# Results for channel: AF7
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  474.8176
# Min. group size:        150         Log-Likelihood:         -50197.2454
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     38.336    4.862 7.885 0.000 28.806 47.866
# state                          1.122    1.989 0.564 0.573 -2.777  5.021
# subject_session Var         1177.728   10.997
# subject_session x state Cov -111.259    3.265
# state Var                    189.129    1.837
# =======================================================================
#
# Results for channel: AF3
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  569.3180
# Min. group size:        150         Log-Likelihood:         -51203.8617
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     41.421    5.269 7.861 0.000 31.094 51.749
# state                          0.510    2.147 0.238 0.812 -3.697  4.717
# subject_session Var         1382.992   11.753
# subject_session x state Cov -110.998    3.455
# state Var                    219.887    1.951
# =======================================================================
#
# Results for channel: F1
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      band_power
# No. Observations:      11103        Method:                  REML
# No. Groups:            50           Scale:                   611.1662
# Min. group size:       150          Log-Likelihood:          -51597.5231
# Max. group size:       270          Converged:               Yes
# Mean group size:       222.1
# ------------------------------------------------------------------------
#                              Coef.   Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                     42.573    5.276  8.070 0.000 32.233 52.913
# state                         -0.049    2.294 -0.021 0.983 -4.545  4.447
# subject_session Var         1386.034   11.404
# subject_session x state Cov -111.133    3.561
# state Var                    251.834    2.150
# ========================================================================
#
# Results for channel: F3
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  464.6947
# Min. group size:        150         Log-Likelihood:         -50074.3643
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     37.751    4.513 8.364 0.000 28.905 46.597
# state                          0.419    1.929 0.217 0.828 -3.363  4.201
# subject_session Var         1014.280    9.566
# subject_session x state Cov  -64.282    2.922
# state Var                    177.558    1.745
# =======================================================================
#
# Results for channel: F5
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  487.5251
# Min. group size:       150         Log-Likelihood:         -50332.0438
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    35.239    4.288 8.218 0.000 26.834 43.644
# state                         0.216    1.817 0.119 0.905 -3.345  3.777
# subject_session Var         915.055    8.431
# subject_session x state Cov -85.602    2.589
# state Var                   156.073    1.511
# ======================================================================
#
# Results for channel: F7
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      band_power
# No. Observations:      11103        Method:                  REML
# No. Groups:            50           Scale:                   367.9206
# Min. group size:       150          Log-Likelihood:          -48777.4517
# Max. group size:       270          Converged:               Yes
# Mean group size:       222.1
# ------------------------------------------------------------------------
#                              Coef.   Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                     34.769    4.266  8.149 0.000 26.407 43.130
# state                         -0.240    1.688 -0.142 0.887 -3.547  3.068
# subject_session Var          906.759    9.614
# subject_session x state Cov -128.603    2.858
# state Var                    135.615    1.500
# ========================================================================
#
# Results for channel: FT7
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      band_power
# No. Observations:      11103        Method:                  REML
# No. Groups:            50           Scale:                   260.9982
# Min. group size:       150          Log-Likelihood:          -46874.0252
# Max. group size:       270          Converged:               Yes
# Mean group size:       222.1
# ------------------------------------------------------------------------
#                              Coef.   Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                     30.610    3.654  8.377 0.000 23.449 37.772
# state                         -0.777    1.487 -0.523 0.601 -3.691  2.136
# subject_session Var          665.208    8.365
# subject_session x state Cov -105.367    2.585
# state Var                    105.686    1.383
# ========================================================================
#
# Results for channel: FC5
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  253.2875
# Min. group size:       150         Log-Likelihood:         -46694.3487
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    25.949    3.057 8.490 0.000 19.958 31.940
# state                         0.439    1.278 0.343 0.731 -2.067  2.944
# subject_session Var         464.827    5.943
# subject_session x state Cov -61.351    1.845
# state Var                    77.040    1.038
# ======================================================================
#
# Results for channel: FC3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  256.7186
# Min. group size:       150         Log-Likelihood:         -46780.2535
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    28.435    3.168 8.977 0.000 22.227 34.644
# state                         0.929    1.511 0.615 0.539 -2.033  3.890
# subject_session Var         499.367    6.343
# subject_session x state Cov -40.851    2.169
# state Var                   109.427    1.440
# ======================================================================
#
# Results for channel: FC1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  509.9921
# Min. group size:       150         Log-Likelihood:         -50584.9985
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    34.470    4.064 8.483 0.000 26.505 42.434
# state                         1.116    2.094 0.533 0.594 -2.988  5.220
# subject_session Var         821.019    7.406
# subject_session x state Cov -59.432    2.722
# state Var                   209.776    1.961
# ======================================================================
#
# Results for channel: C1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  233.3287
# Min. group size:       150         Log-Likelihood:         -46257.8882
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    21.674    2.327 9.315 0.000 17.114 26.235
# state                         3.799    2.160 1.758 0.079 -0.435  8.032
# subject_session Var         268.613    3.585
# subject_session x state Cov   4.298    2.349
# state Var                   229.018    3.091
# ======================================================================
#
# Results for channel: C3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  172.5079
# Min. group size:       150         Log-Likelihood:         -44569.7235
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    19.506    1.997 9.768 0.000 15.592 23.420
# state                         2.117    1.470 1.441 0.150 -0.763  4.998
# subject_session Var         197.812    3.078
# subject_session x state Cov  18.254    1.607
# state Var                   104.821    1.662
# ======================================================================
#
# Results for channel: C5
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  199.8098
# Min. group size:       150         Log-Likelihood:         -45370.4622
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    20.175    2.191 9.208 0.000 15.880 24.469
# state                         0.867    1.143 0.759 0.448 -1.373  3.107
# subject_session Var         238.212    3.438
# subject_session x state Cov   9.478    1.267
# state Var                    61.604    0.934
# ======================================================================
#
# Results for channel: T7
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  309.2467
# Min. group size:        150         Log-Likelihood:         -47822.4793
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     30.874    3.536 8.732 0.000 23.944 37.803
# state                          0.451    2.041 0.221 0.825 -3.550  4.452
# subject_session Var          622.265    7.213
# subject_session x state Cov -117.004    3.092
# state Var                    202.640    2.395
# =======================================================================
#
# Results for channel: TP7
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      band_power
# No. Observations:      11103        Method:                  REML
# No. Groups:            50           Scale:                   441.3979
# Min. group size:       150          Log-Likelihood:          -49792.8399
# Max. group size:       270          Converged:               Yes
# Mean group size:       222.1
# ------------------------------------------------------------------------
#                              Coef.   Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                     39.217    4.685  8.370 0.000 30.034 48.400
# state                         -1.374    2.046 -0.672 0.502 -5.385  2.636
# subject_session Var         1093.620   10.580
# subject_session x state Cov -179.508    3.490
# state Var                    201.161    2.011
# ========================================================================
#
# Results for channel: CP5
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  258.3522
# Min. group size:       150         Log-Likelihood:         -46820.6784
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    26.883    3.634 7.397 0.000 19.760 34.005
# state                         0.778    1.452 0.536 0.592 -2.069  3.624
# subject_session Var         658.005    8.299
# subject_session x state Cov  16.516    2.343
# state Var                   100.691    1.325
# ======================================================================
#
# Results for channel: CP3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  307.4097
# Min. group size:       150         Log-Likelihood:         -47766.3808
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    23.825    2.857 8.338 0.000 18.225 29.425
# state                         3.709    1.621 2.288 0.022  0.532  6.887
# subject_session Var         405.442    4.719
# subject_session x state Cov  97.211    2.041
# state Var                   125.736    1.517
# ======================================================================
#
# Results for channel: CP1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  396.2373
# Min. group size:       150         Log-Likelihood:         -49182.5708
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    22.959    2.518 9.117 0.000 18.023 27.894
# state                         4.987    2.553 1.953 0.051 -0.017  9.990
# subject_session Var         313.501    3.220
# subject_session x state Cov  60.442    2.342
# state Var                   318.551    3.311
# ======================================================================
#
# Results for channel: P1
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  854.3472
# Min. group size:        150         Log-Likelihood:         -53458.2550
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     41.273    5.574 7.405 0.000 30.348 52.197
# state                          3.516    3.129 1.124 0.261 -2.617  9.648
# subject_session Var         1545.662   10.762
# subject_session x state Cov -160.627    4.345
# state Var                    473.720    3.390
# =======================================================================
#
# Results for channel: P3
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  922.7139
# Min. group size:        150         Log-Likelihood:         -53888.7706
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     48.510    7.095 6.838 0.000 34.605 62.415
# state                          2.053    2.783 0.738 0.461 -3.401  7.507
# subject_session Var         2508.323   16.782
# subject_session x state Cov   21.637    4.645
# state Var                    370.119    2.580
# =======================================================================
#
# Results for channel: P5
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  1317.1546
# Min. group size:        150         Log-Likelihood:         -55874.5073
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     62.076   10.309 6.021 0.000 41.869 82.282
# state                          1.024    3.454 0.296 0.767 -5.745  7.793
# subject_session Var         5302.308   29.621
# subject_session x state Cov -378.205    7.166
# state Var                    572.118    3.322
# =======================================================================
#
# Results for channel: P7
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                  MixedLM      Dependent Variable:      band_power
# No. Observations:       11103        Method:                  REML
# No. Groups:             50           Scale:                   6247.1947
# Min. group size:        150          Log-Likelihood:          -64495.6314
# Max. group size:        270          Converged:               Yes
# Mean group size:        222.1
# -------------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z|  [0.025  0.975]
# -------------------------------------------------------------------------
# Intercept                     82.965   11.699 7.091 0.000  60.034 105.895
# state                          3.278    9.631 0.340 0.734 -15.598  22.154
# subject_session Var         6787.209   17.513
# subject_session x state Cov -732.143   10.268
# state Var                   4522.153   11.861
# =========================================================================
#
# Results for channel: P9
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  1501.7945
# Min. group size:        150         Log-Likelihood:         -56599.4689
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     72.736    8.866 8.204 0.000 55.359 90.114
# state                          5.259    4.270 1.232 0.218 -3.111 13.629
# subject_session Var         3916.831   20.531
# subject_session x state Cov -360.661    7.111
# state Var                    884.037    4.762
# =======================================================================
#
# Results for channel: PO7
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:                   MixedLM      Dependent Variable:      band_power
# No. Observations:        11103        Method:                  REML
# No. Groups:              50           Scale:                   7121.2884
# Min. group size:         150          Log-Likelihood:          -65247.9953
# Max. group size:         270          Converged:               Yes
# Mean group size:         222.1
# --------------------------------------------------------------------------
#                               Coef.   Std.Err.   z   P>|z|  [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                     143.056   28.129 5.086 0.000  87.923 198.188
# state                           2.524    8.146 0.310 0.757 -13.441  18.489
# subject_session Var         39498.387   94.924
# subject_session x state Cov -4034.555   20.591
# state Var                    3185.960    7.950
# ==========================================================================
#
# Results for channel: PO3
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:                   MixedLM      Dependent Variable:      band_power
# No. Observations:        11103        Method:                  REML
# No. Groups:              50           Scale:                   4794.0994
# Min. group size:         150          Log-Likelihood:          -63046.5823
# Max. group size:         270          Converged:               Yes
# Mean group size:         222.1
# --------------------------------------------------------------------------
#                               Coef.   Std.Err.   z   P>|z|  [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                     108.254   20.027 5.405 0.000  69.002 147.506
# state                           0.863    7.285 0.118 0.906 -13.416  15.142
# subject_session Var         20010.319   58.635
# subject_session x state Cov -3278.651   16.555
# state Var                    2565.220    7.759
# ==========================================================================
#
# Results for channel: O1
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:                   MixedLM      Dependent Variable:      band_power
# No. Observations:        11103        Method:                  REML
# No. Groups:              50           Scale:                   4752.8897
# Min. group size:         150          Log-Likelihood:          -62994.5361
# Max. group size:         270          Converged:               Yes
# Mean group size:         222.1
# --------------------------------------------------------------------------
#                               Coef.   Std.Err.   z   P>|z|  [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                     117.891   18.977 6.212 0.000  80.697 155.085
# state                           1.542    6.562 0.235 0.814 -11.320  14.404
# subject_session Var         17962.982   52.877
# subject_session x state Cov -1890.993   13.508
# state Var                    2065.444    6.313
# ==========================================================================
#
# Results for channel: Iz
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  1482.0604
# Min. group size:        150         Log-Likelihood:         -56511.7202
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     68.708    7.718 8.903 0.000 53.582 83.834
# state                          0.448    3.854 0.116 0.907 -7.105  8.002
# subject_session Var         2964.661   15.668
# subject_session x state Cov -572.341    5.936
# state Var                    715.283    3.905
# =======================================================================
#
# Results for channel: Oz
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      band_power
# No. Observations:      11103        Method:                  REML
# No. Groups:            50           Scale:                   2819.1302
# Min. group size:       150          Log-Likelihood:          -60086.8891
# Max. group size:       270          Converged:               Yes
# Mean group size:       222.1
# ------------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025  0.975]
# ------------------------------------------------------------------------
# Intercept                     85.890   11.148 7.705 0.000 64.041 107.739
# state                          3.279    5.482 0.598 0.550 -7.465  14.023
# subject_session Var         6187.919   23.697
# subject_session x state Cov -761.416    8.484
# state Var                   1450.457    5.717
# ========================================================================
#
# Results for channel: POz
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                  MixedLM      Dependent Variable:      band_power
# No. Observations:       11103        Method:                  REML
# No. Groups:             50           Scale:                   4833.5612
# Min. group size:        150          Log-Likelihood:          -63082.1990
# Max. group size:        270          Converged:               Yes
# Mean group size:        222.1
# -------------------------------------------------------------------------
#                               Coef.   Std.Err.   z   P>|z| [0.025  0.975]
# -------------------------------------------------------------------------
# Intercept                      91.597   14.827 6.178 0.000 62.535 120.658
# state                           6.408    7.469 0.858 0.391 -8.230  21.046
# subject_session Var         10948.855   32.078
# subject_session x state Cov -1375.129   11.750
# state Var                    2699.636    8.102
# =========================================================================
#
# Results for channel: Pz
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  1086.2927
# Min. group size:        150         Log-Likelihood:         -54790.6791
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     43.792    5.912 7.407 0.000 32.204 55.379
# state                          5.090    3.665 1.389 0.165 -2.094 12.274
# subject_session Var         1737.815   10.736
# subject_session x state Cov -150.663    4.748
# state Var                    651.680    4.121
# =======================================================================
#
# Results for channel: CPz
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  651.3290
# Min. group size:       150         Log-Likelihood:         -51948.4943
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    26.704    3.528 7.570 0.000 19.790 33.618
# state                         6.653    3.489 1.907 0.057 -0.186 13.492
# subject_session Var         616.314    4.942
# subject_session x state Cov 125.211    3.513
# state Var                   596.794    4.827
# ======================================================================
#
# Results for channel: Fpz
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  698.0536
# Min. group size:        150         Log-Likelihood:         -52338.6957
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     44.646    5.920 7.542 0.000 33.044 56.249
# state                          1.165    2.500 0.466 0.641 -3.736  6.065
# subject_session Var         1745.787   13.430
# subject_session x state Cov -135.725    4.076
# state Var                    299.706    2.391
# =======================================================================
#
# Results for channel: Fp2
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  643.8600
# Min. group size:        150         Log-Likelihood:         -51890.4841
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     43.753    5.747 7.614 0.000 32.490 55.016
# state                          1.170    2.406 0.486 0.627 -3.546  5.887
# subject_session Var         1645.301   13.171
# subject_session x state Cov -145.300    3.987
# state Var                    277.663    2.308
# =======================================================================
#
# Results for channel: AF8
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  489.6261
# Min. group size:        150         Log-Likelihood:         -50371.2020
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     39.544    5.126 7.714 0.000 29.497 49.592
# state                          0.542    2.125 0.255 0.799 -3.624  4.707
# subject_session Var         1309.521   12.027
# subject_session x state Cov -157.620    3.671
# state Var                    216.799    2.063
# =======================================================================
#
# Results for channel: AF4
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      band_power
# No. Observations:      11103        Method:                  REML
# No. Groups:            50           Scale:                   610.2868
# Min. group size:       150          Log-Likelihood:          -51594.7002
# Max. group size:       270          Converged:               Yes
# Mean group size:       222.1
# ------------------------------------------------------------------------
#                              Coef.   Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                     43.682    5.633  7.755 0.000 32.642 54.722
# state                         -0.215    2.404 -0.090 0.929 -4.926  4.495
# subject_session Var         1580.804   12.993
# subject_session x state Cov -149.691    4.018
# state Var                    277.568    2.367
# ========================================================================
#
# Results for channel: AFz
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  744.2951
# Min. group size:        150         Log-Likelihood:         -52693.1107
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     45.981    5.935 7.748 0.000 34.350 57.613
# state                          0.013    2.583 0.005 0.996 -5.050  5.075
# subject_session Var         1754.286   13.074
# subject_session x state Cov -153.518    4.103
# state Var                    319.822    2.473
# =======================================================================
#
# Results for channel: Fz
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      band_power
# No. Observations:      11103        Method:                  REML
# No. Groups:            50           Scale:                   660.0052
# Min. group size:       150          Log-Likelihood:          -52029.7300
# Max. group size:       270          Converged:               Yes
# Mean group size:       222.1
# ------------------------------------------------------------------------
#                              Coef.   Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                     44.757    5.748  7.787 0.000 33.492 56.022
# state                         -0.227    2.569 -0.088 0.930 -5.261  4.808
# subject_session Var         1645.723   13.015
# subject_session x state Cov -168.681    4.219
# state Var                    317.736    2.598
# ========================================================================
#
# Results for channel: F2
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      band_power
# No. Observations:      11103        Method:                  REML
# No. Groups:            50           Scale:                   653.4611
# Min. group size:       150          Log-Likelihood:          -51971.6693
# Max. group size:       270          Converged:               Yes
# Mean group size:       222.1
# ------------------------------------------------------------------------
#                              Coef.   Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                     44.246    5.621  7.872 0.000 33.230 55.263
# state                         -0.012    2.465 -0.005 0.996 -4.842  4.819
# ...
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  357.0215
# Min. group size:        150         Log-Likelihood:         -48599.2899
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                    30.859    3.026 10.197 0.000 24.928 36.791
# state                         1.671    1.712  0.976 0.329 -1.685  5.026
# subject_session Var         454.665    4.905
# subject_session x state Cov  22.253    1.963
# state Var                   139.955    1.568
# =======================================================================
#
# Results for channel: TP8
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  702.3467
# Min. group size:        150         Log-Likelihood:         -52365.2116
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     45.331    5.020 9.031 0.000 35.493 55.170
# state                          3.766    2.501 1.506 0.132 -1.135  8.667
# subject_session Var         1253.532    9.629
# subject_session x state Cov   37.060    3.386
# state Var                    299.681    2.382
# =======================================================================
#
# Results for channel: CP6
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  302.0657
# Min. group size:       150         Log-Likelihood:         -47673.8141
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    30.132    3.241 9.298 0.000 23.781 36.484
# state                         1.575    1.428 1.103 0.270 -1.223  4.374
# subject_session Var         522.355    6.120
# subject_session x state Cov  35.394    1.923
# state Var                    96.388    1.187
# ======================================================================
#
# Results for channel: CP4
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  370.3062
# Min. group size:       150         Log-Likelihood:         -48797.6929
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    26.838    3.148 8.525 0.000 20.668 33.008
# state                         3.021    1.601 1.887 0.059 -0.117  6.158
# subject_session Var         492.191    5.204
# subject_session x state Cov  62.161    1.924
# state Var                   121.314    1.348
# ======================================================================
#
# Results for channel: CP2
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  356.3986
# Min. group size:       150         Log-Likelihood:         -48602.5795
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    25.544    2.936 8.701 0.000 19.790 31.297
# state                         3.833    2.298 1.668 0.095 -0.671  8.337
# subject_session Var         427.672    4.621
# subject_session x state Cov  31.488    2.563
# state Var                   257.481    2.829
# ======================================================================
#
# Results for channel: P2
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  942.4544
# Min. group size:        150         Log-Likelihood:         -53999.3544
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     44.977    5.837 7.705 0.000 33.537 56.418
# state                          3.281    3.044 1.078 0.281 -2.685  9.247
# subject_session Var         1695.163   11.235
# subject_session x state Cov -142.185    4.192
# state Var                    445.841    3.047
# =======================================================================
#
# Results for channel: P4
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  1094.8272
# Min. group size:        150         Log-Likelihood:         -54836.0805
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     53.270    6.956 7.658 0.000 39.637 66.903
# state                          3.485    3.241 1.075 0.282 -2.867  9.837
# subject_session Var         2409.206   14.807
# subject_session x state Cov  -72.503    4.885
# state Var                    504.959    3.213
# =======================================================================
#
# Results for channel: P6
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       11103       Method:                 REML
# No. Groups:             50          Scale:                  1937.2117
# Min. group size:        150         Log-Likelihood:         -58008.7882
# Max. group size:        270         Converged:              Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     72.144    9.931 7.265 0.000 52.679 91.608
# state                          4.292    4.466 0.961 0.336 -4.460 13.045
# subject_session Var         4913.690   22.671
# subject_session x state Cov  -57.365    7.204
# state Var                    961.329    4.588
# =======================================================================
#
# Results for channel: P8
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      band_power
# No. Observations:      11103        Method:                  REML
# No. Groups:            50           Scale:                   3345.6105
# Min. group size:       150          Log-Likelihood:          -61036.1099
# Max. group size:       270          Converged:               Yes
# Mean group size:       222.1
# ------------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025  0.975]
# ------------------------------------------------------------------------
# Intercept                     97.846   12.574 7.781 0.000 73.201 122.491
# state                          6.974    5.582 1.249 0.212 -3.967  17.914
# subject_session Var         7875.465   27.682
# subject_session x state Cov -743.367    8.875
# state Var                   1496.138    5.442
# ========================================================================
#
# Results for channel: P10
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:                   MixedLM      Dependent Variable:      band_power
# No. Observations:        11103        Method:                  REML
# No. Groups:              50           Scale:                   2779.7857
# Min. group size:         150          Log-Likelihood:          -60020.9816
# Max. group size:         270          Converged:               Yes
# Mean group size:         222.1
# --------------------------------------------------------------------------
#                               Coef.   Std.Err.   z   P>|z|  [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                      94.012   12.791 7.350 0.000  68.942 119.081
# state                           0.545    6.958 0.078 0.938 -13.093  14.183
# subject_session Var          8154.815   31.427
# subject_session x state Cov -2406.797   13.757
# state Var                    2369.626    9.291
# ==========================================================================
#
# Results for channel: PO8
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:                   MixedLM      Dependent Variable:      band_power
# No. Observations:        11103        Method:                  REML
# No. Groups:              50           Scale:                   11087.4725
# Min. group size:         150          Log-Likelihood:          -67699.9181
# Max. group size:         270          Converged:               Yes
# Mean group size:         222.1
# --------------------------------------------------------------------------
#                               Coef.   Std.Err.   z   P>|z|  [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                     160.924   27.145 5.928 0.000 107.720 214.127
# state                          13.805   11.200 1.233 0.218  -8.147  35.758
# subject_session Var         36742.232   70.849
# subject_session x state Cov -2874.511   21.022
# state Var                    6067.563   12.055
# ==========================================================================
#
# Results for channel: PO4
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                  MixedLM      Dependent Variable:      band_power
# No. Observations:       11103        Method:                  REML
# No. Groups:             50           Scale:                   5652.5087
# Min. group size:        150          Log-Likelihood:          -63947.7884
# Max. group size:        270          Converged:               Yes
# Mean group size:        222.1
# -------------------------------------------------------------------------
#                               Coef.   Std.Err.   z   P>|z| [0.025  0.975]
# -------------------------------------------------------------------------
# Intercept                     105.673   15.483 6.825 0.000 75.327 136.020
# state                           7.612    7.677 0.991 0.321 -7.436  22.660
# subject_session Var         11935.307   32.290
# subject_session x state Cov  -888.497   11.434
# state Var                    2842.765    7.923
# =========================================================================
#
# Results for channel: O2
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                  MixedLM      Dependent Variable:      band_power
# No. Observations:       11103        Method:                  REML
# No. Groups:             50           Scale:                   4845.3664
# Min. group size:        150          Log-Likelihood:          -63098.6555
# Max. group size:        270          Converged:               Yes
# Mean group size:        222.1
# -------------------------------------------------------------------------
#                               Coef.   Std.Err.   z   P>|z| [0.025  0.975]
# -------------------------------------------------------------------------
# Intercept                     109.243   17.106 6.386 0.000 75.715 142.771
# state                           5.541    7.037 0.787 0.431 -8.251  19.333
# subject_session Var         14587.744   42.563
# subject_session x state Cov -1906.228   12.985
# state Var                    2386.402    7.189
# =========================================================================

# %% [markdown]
# # Z-score normalize whitin-subject
# Z-score normalize whitin-subject across epochs and fit new models for easier interpretations

# %%
# create a new column with z-scores within each state
def z_score_within_state(df):
    grouped = df.groupby(['subject_session'])
    df['z_score'] = grouped['band_power'].transform(lambda x: (x - x.mean()) / x.std())
    return df

# apply the z-score function to each channel dataframe
df_channels_z = []
for df_channel in df_channels:
    df_channel_z = z_score_within_state(df_channel)
    df_channels_z.append(df_channel_z)

# %%
# Fit mixed effects model per channel with z-score insted of band_power

results_per_channel_z = {}

for df_channel in df_channels_z:
    channel_name = df_channel['channel'].iloc[0] if 'channel' in df_channel else None
    # Fit the mixed effects model: alpha_power ~ state + (state | subject_session)
    # Use 'band_power' as the dependent variable
    # 'state' as fixed effect, random intercept and slope for 'subject_session'
    model = smf.mixedlm(
        "z_score ~ state",
        df_channel,
        groups="subject_session",
        re_formula="~state"
    )
    result = model.fit(method="lbfgs")
    results_per_channel_z[channel_name] = result

# Print summary for all channels
for channel in results_per_channel_z:
    print(f"Results for channel: {channel}")
    print(results_per_channel_z[channel].summary())
# Out:
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 67.095800
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 84.535422
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 99.302407
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 131.500511
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 144.329633
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 130.297107
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 201.289019
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 162.956906
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 155.682463
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 133.448101
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 28.058303
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 55.226597
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 2.819330
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 133.312811
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 184.046839
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 48.310572
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 120.737952
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 165.124046
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 162.963949
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 146.587450
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 74.338399
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 59.315586
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 184.580104
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 35.324908
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Results for channel: Fp1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9181
# Min. group size:       150         Log-Likelihood:         -15359.0241
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.043    0.041 -1.050 0.294 -0.125  0.038
# state                        0.091    0.081  1.131 0.258 -0.067  0.249
# subject_session Var          0.077    0.022
# subject_session x state Cov -0.155    0.038
# state Var                    0.309    0.070
# ======================================================================
#
# Results for channel: AF7
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9181
# Min. group size:       150         Log-Likelihood:         -15358.2314
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.043    0.041 -1.062 0.288 -0.123  0.037
# state                        0.090    0.079  1.133 0.257 -0.066  0.246
# subject_session Var          0.075    0.021
# subject_session x state Cov -0.149    0.035
# state Var                    0.299    0.066
# ======================================================================
#
# Results for channel: AF3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9160
# Min. group size:       150         Log-Likelihood:         -15366.1352
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.029    0.053 -0.539 0.590 -0.133  0.076
# state                        0.060    0.107  0.566 0.572 -0.149  0.270
# subject_session Var          0.134    0.074
# subject_session x state Cov -0.271    0.146
# state Var                    0.554    0.287
# ======================================================================
#
# Results for channel: F1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9235
# Min. group size:       150         Log-Likelihood:         -15394.6812
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.001    0.045  0.025 0.980 -0.087  0.089
# state                       -0.000    0.087 -0.001 0.999 -0.170  0.169
# subject_session Var          0.092
# subject_session x state Cov -0.182    0.042
# state Var                    0.357    0.101
# ======================================================================
#
# Results for channel: F3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9065
# Min. group size:       150         Log-Likelihood:         -15315.8179
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.002    0.047  0.041 0.968 -0.090  0.094
# state                       -0.008    0.106 -0.079 0.937 -0.215  0.199
# subject_session Var          0.102    0.052
# subject_session x state Cov -0.232    0.141
# state Var                    0.542    0.354
# ======================================================================
#
# Results for channel: F5
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9177
# Min. group size:       150         Log-Likelihood:         -15358.9406
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.018    0.043 -0.415 0.678 -0.103  0.067
# state                        0.034    0.085  0.406 0.685 -0.131  0.200
# subject_session Var          0.086    0.030
# subject_session x state Cov -0.171    0.047
# state Var                    0.341    0.083
# ======================================================================
#
# Results for channel: F7
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9201
# Min. group size:       150         Log-Likelihood:         -15370.0567
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.004    0.041 -0.088 0.930 -0.084  0.077
# state                        0.006    0.079  0.074 0.941 -0.150  0.162
# subject_session Var          0.076    0.022
# subject_session x state Cov -0.150    0.037
# state Var                    0.298    0.066
# ======================================================================
#
# Results for channel: FT7
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9302
# Min. group size:       150         Log-Likelihood:         -15429.0850
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.020    0.040  0.496 0.620 -0.059  0.099
# state                       -0.036    0.078 -0.464 0.642 -0.188  0.116
# subject_session Var          0.073    0.030
# subject_session x state Cov -0.143    0.043
# state Var                    0.284    0.069
# ======================================================================
#
# Results for channel: FC5
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9183
# Min. group size:       150         Log-Likelihood:         -15375.6348
# Max. group size:       270         Converged:              No
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.022    0.055 -0.401 0.688 -0.129  0.085
# state                        0.043    0.110  0.391 0.696 -0.172  0.258
# subject_session Var          0.141    0.131
# subject_session x state Cov -0.287    0.264
# state Var                    0.586    0.530
# ======================================================================
#
# Results for channel: FC3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9092
# Min. group size:       150         Log-Likelihood:         -15308.5447
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.031    0.045 -0.684 0.494 -0.118  0.057
# state                        0.058    0.087  0.667 0.505 -0.112  0.228
# subject_session Var          0.092    0.026
# subject_session x state Cov -0.181    0.044
# state Var                    0.359    0.083
# ======================================================================
#
# Results for channel: FC1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9128
# Min. group size:       150         Log-Likelihood:         -15337.4597
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.010    0.051  0.202 0.840 -0.089  0.110
# state                       -0.016    0.100 -0.164 0.870 -0.212  0.179
# subject_session Var          0.121    0.039
# subject_session x state Cov -0.241    0.085
# state Var                    0.481    0.172
# ======================================================================
#
# Results for channel: C1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.8918
# Min. group size:       150         Log-Likelihood:         -15222.0991
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.051    0.064 -0.794 0.427 -0.177  0.075
# state                        0.109    0.126  0.867 0.386 -0.137  0.355
# subject_session Var          0.199    0.156
# subject_session x state Cov -0.392    0.320
# ...
# state Var                    0.414    0.150
# ======================================================================
#
# Results for channel: T8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9288
# Min. group size:       150         Log-Likelihood:         -15433.3194
# Max. group size:       270         Converged:              No
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.003    0.045 -0.068 0.946 -0.092  0.086
# state                        0.010    0.092  0.108 0.914 -0.171  0.191
# subject_session Var          0.095    0.033
# subject_session x state Cov -0.196    0.061
# state Var                    0.408    0.104
# ======================================================================
#
# Results for channel: TP8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9198
# Min. group size:       150         Log-Likelihood:         -15383.2546
# Max. group size:       270         Converged:              No
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.007    0.052 -0.128 0.898 -0.109  0.096
# state                        0.013    0.100  0.131 0.896 -0.183  0.209
# subject_session Var          0.128    0.033
# subject_session x state Cov -0.249    0.078
# state Var                    0.485    0.174
# ======================================================================
#
# Results for channel: CP6
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9198
# Min. group size:       150         Log-Likelihood:         -15369.5523
# Max. group size:       270         Converged:              No
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.019    0.041 -0.463 0.643 -0.100  0.062
# state                        0.040    0.080  0.505 0.614 -0.117  0.197
# subject_session Var          0.077    0.026
# subject_session x state Cov -0.153    0.041
# state Var                    0.304    0.070
# ======================================================================
#
# Results for channel: CP4
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9284
# Min. group size:       150         Log-Likelihood:         -15423.5545
# Max. group size:       270         Converged:              No
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.043    0.044 -0.976 0.329 -0.130  0.044
# state                        0.096    0.085  1.133 0.257 -0.070  0.262
# subject_session Var          0.090    0.017
# subject_session x state Cov -0.175    0.049
# state Var                    0.342    0.104
# ======================================================================
#
# Results for channel: CP2
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9242
# Min. group size:       150         Log-Likelihood:         -15405.3874
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.037    0.050 -0.743 0.457 -0.134  0.060
# state                        0.084    0.096  0.870 0.384 -0.105  0.272
# subject_session Var          0.115    0.048
# subject_session x state Cov -0.226    0.097
# state Var                    0.445    0.188
# ======================================================================
#
# Results for channel: P2
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9067
# Min. group size:       150         Log-Likelihood:         -15298.8831
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.030    0.043 -0.701 0.484 -0.114  0.054
# state                        0.064    0.091  0.696 0.486 -0.116  0.243
# subject_session Var          0.083    0.022
# subject_session x state Cov -0.182    0.058
# state Var                    0.401    0.149
# ======================================================================
#
# Results for channel: P4
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9085
# Min. group size:       150         Log-Likelihood:         -15310.1688
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.061    0.050 -1.203 0.229 -0.160  0.038
# state                        0.128    0.094  1.363 0.173 -0.056  0.312
# subject_session Var          0.119    0.081
# subject_session x state Cov -0.224    0.134
# state Var                    0.424    0.214
# ======================================================================
#
# Results for channel: P6
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9008
# Min. group size:       150         Log-Likelihood:         -15265.5992
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.038    0.052 -0.728 0.467 -0.141  0.065
# state                        0.073    0.102  0.713 0.476 -0.128  0.273
# subject_session Var          0.129    0.033
# subject_session x state Cov -0.256    0.076
# state Var                    0.507    0.161
# ======================================================================
#
# Results for channel: P8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9027
# Min. group size:       150         Log-Likelihood:         -15276.1030
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.047    0.050 -0.936 0.349 -0.145  0.051
# state                        0.091    0.099  0.921 0.357 -0.103  0.285
# subject_session Var          0.117    0.026
# subject_session x state Cov -0.235    0.066
# state Var                    0.474    0.142
# ======================================================================
#
# Results for channel: P10
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.8916
# Min. group size:       150         Log-Likelihood:         -15212.0849
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.005    0.049  0.106 0.916 -0.091  0.101
# state                       -0.007    0.101 -0.072 0.942 -0.205  0.190
# subject_session Var          0.112    0.030
# subject_session x state Cov -0.234    0.047
# state Var                    0.491
# ======================================================================
#
# Results for channel: PO8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.8955
# Min. group size:       150         Log-Likelihood:         -15262.9130
# Max. group size:       270         Converged:              No
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.029    0.067 -0.438 0.662 -0.161  0.102
# state                        0.053    0.128  0.413 0.679 -0.198  0.304
# subject_session Var          0.217    0.161
# subject_session x state Cov -0.413    0.334
# state Var                    0.805    0.688
# ======================================================================
#
# Results for channel: PO4
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.8942
# Min. group size:       150         Log-Likelihood:         -15221.7840
# Max. group size:       270         Converged:              Yes
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.035    0.049 -0.714 0.475 -0.132  0.061
# state                        0.068    0.096  0.714 0.475 -0.119  0.256
# subject_session Var          0.113    0.037
# subject_session x state Cov -0.224    0.062
# state Var                    0.442    0.110
# ======================================================================
#
# Results for channel: O2
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     z_score
# No. Observations:      11103       Method:                 REML
# No. Groups:            50          Scale:                  0.9008
# Min. group size:       150         Log-Likelihood:         -15265.4694
# Max. group size:       270         Converged:              No
# Mean group size:       222.1
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.020    0.052 -0.378 0.705 -0.122  0.082
# state                        0.037    0.102  0.360 0.719 -0.164  0.238
# subject_session Var          0.127    0.034
# subject_session x state Cov -0.254    0.077
# state Var                    0.508    0.158
# ======================================================================

# %%
# Fit mixed effects model per channel with z-score insted of band_power

results_per_channel_z = {}

for df_channel in df_channels_z:
    channel_name = df_channel['channel'].iloc[0] if 'channel' in df_channel else None
    # Fit the mixed effects model: alpha_power ~ state + (state | subject_session)
    # Use 'band_power' as the dependent variable
    # 'state' as fixed effect, random intercept and slope for 'subject_session'
    model = smf.mixedlm(
        "z_score ~ state",
        df_channel,
        groups="subject_session",
        re_formula="~1"
    )
    result = model.fit(method="lbfgs")
    results_per_channel_z[channel_name] = result

# Print summary for all channels
for channel in results_per_channel_z:
    print(f"Results for channel: {channel}")
    print(results_per_channel_z[channel].summary())
# Out:
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# ...
# Max. group size:        270           Converged:                Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                     Coef.  Std.Err.    z   P>|z|    [0.025     0.975]
# -----------------------------------------------------------------------
# Intercept           0.008 208678.696 0.000 1.000 -409002.721 409002.737
# state               0.011      0.019 0.577 0.564      -0.026      0.048
# subject_session Var 0.000
# =======================================================================
#
# Results for channel: C6
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         11103         Method:                   REML
# No. Groups:               50            Scale:                    0.9950
# Min. group size:          150           Log-Likelihood:           inf
# Max. group size:          270           Converged:                Yes
# Mean group size:          222.1
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.002 208611.213 -0.000 1.000 -408870.466 408870.462
# state                0.052      0.019  2.742 0.006       0.015      0.090
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: T8
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM  Dependent Variable:  z_score
# No. Observations:    11103    Method:              REML
# No. Groups:          50       Scale:               0.9956
# Min. group size:     150      Log-Likelihood:      -15735.9802
# Max. group size:     270      Converged:           Yes
# Mean group size:     222.1
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           -0.004    0.013 -0.277 0.782 -0.030  0.022
# state                0.015    0.019  0.781 0.435 -0.022  0.052
# subject_session Var  0.000
# ==============================================================
#
# Results for channel: TP8
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         11103         Method:                   REML
# No. Groups:               50            Scale:                    0.9957
# Min. group size:          150           Log-Likelihood:           inf
# Max. group size:          270           Converged:                Yes
# Mean group size:          222.1
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.000 208679.510 -0.000 1.000 -409004.325 409004.324
# state                0.009      0.019  0.496 0.620      -0.028      0.047
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: CP6
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         11103         Method:                   REML
# No. Groups:               50            Scale:                    0.9952
# Min. group size:          150           Log-Likelihood:           inf
# Max. group size:          270           Converged:                Yes
# Mean group size:          222.1
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.010 208635.869 -0.000 1.000 -408918.799 408918.780
# state                0.042      0.019  2.211 0.027       0.005      0.079
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: CP4
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM  Dependent Variable:  z_score
# No. Observations:    11103    Method:              REML
# No. Groups:          50       Scale:               0.9944
# Min. group size:     150      Log-Likelihood:      -15728.9130
# Max. group size:     270      Converged:           Yes
# Mean group size:     222.1
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           -0.014    0.011 -1.308 0.191 -0.036  0.007
# state                0.105    0.019  5.562 0.000  0.068  0.142
# subject_session Var  0.000
# ==============================================================
#
# Results for channel: CP2
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         11103         Method:                   REML
# No. Groups:               50            Scale:                    0.9936
# Min. group size:          150           Log-Likelihood:           inf
# Max. group size:          270           Converged:                Yes
# Mean group size:          222.1
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.009 208461.638 -0.000 1.000 -408577.312 408577.294
# state                0.092      0.019  4.844 0.000       0.055      0.129
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: P2
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         11103         Method:                   REML
# No. Groups:               50            Scale:                    0.9944
# Min. group size:          150           Log-Likelihood:           inf
# Max. group size:          270           Converged:                Yes
# Mean group size:          222.1
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.002 208552.426 -0.000 1.000 -408755.245 408755.241
# state                0.071      0.019  3.712 0.000       0.033      0.108
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: P4
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         11103         Method:                   REML
# No. Groups:               50            Scale:                    0.9914
# Min. group size:          150           Log-Likelihood:           inf
# Max. group size:          270           Converged:                Yes
# Mean group size:          222.1
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.014 208236.229 -0.000 1.000 -408135.524 408135.496
# state                0.131      0.019  6.896 0.000       0.094      0.168
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: P6
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         11103         Method:                   REML
# No. Groups:               50            Scale:                    0.9944
# Min. group size:          150           Log-Likelihood:           inf
# Max. group size:          270           Converged:                Yes
# Mean group size:          222.1
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.002 208550.247 -0.000 1.000 -408750.976 408750.971
# state                0.071      0.019  3.743 0.000       0.034      0.109
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: P8
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         11103         Method:                   REML
# No. Groups:               50            Scale:                    0.9942
# Min. group size:          150           Log-Likelihood:           inf
# Max. group size:          270           Converged:                Yes
# Mean group size:          222.1
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.013 208529.805 -0.000 1.000 -408710.921 408710.895
# state                0.077      0.019  4.024 0.000       0.039      0.114
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: P10
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         11103         Method:                   REML
# No. Groups:               50            Scale:                    0.9956
# Min. group size:          150           Log-Likelihood:           inf
# Max. group size:          270           Converged:                Yes
# Mean group size:          222.1
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.012 208674.686 -0.000 1.000 -408994.881 408994.857
# state               -0.017      0.019 -0.871 0.384      -0.054      0.021
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: PO8
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         11103         Method:                   REML
# No. Groups:               50            Scale:                    0.9950
# Min. group size:          150           Log-Likelihood:           inf
# Max. group size:          270           Converged:                Yes
# Mean group size:          222.1
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.002 208612.300 -0.000 1.000 -408872.597 408872.592
# state                0.052      0.019  2.720 0.007       0.014      0.089
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: PO4
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         11103         Method:                   REML
# No. Groups:               50            Scale:                    0.9945
# Min. group size:          150           Log-Likelihood:           inf
# Max. group size:          270           Converged:                Yes
# Mean group size:          222.1
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.004 208558.471 -0.000 1.000 -408767.096 408767.089
# state                0.069      0.019  3.624 0.000       0.032      0.106
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: O2
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM       Dependent Variable:       z_score
# No. Observations:       11103         Method:                   REML
# No. Groups:             50            Scale:                    0.9954
# Min. group size:        150           Log-Likelihood:           inf
# Max. group size:        270           Converged:                Yes
# Mean group size:        222.1
# -----------------------------------------------------------------------
#                     Coef.  Std.Err.    z   P>|z|    [0.025     0.975]
# -----------------------------------------------------------------------
# Intercept           0.006 208651.204 0.000 1.000 -408948.838 408948.851
# state               0.034      0.019 1.805 0.071      -0.003      0.072
# subject_session Var 0.000
# =======================================================================

# %% [markdown]
# ### **Store & Summarize Results**
#
# For each model/channel:
#
# - [ ]  Store:
#     - Fixed effect estimate for `state`
#     - p-value
#     - t-statistic (optional)
#     - Number of subjects included
# - [ ]  Save results to `.csv` or `.json`

# %% [markdown]
# ### **Visualize Results**
#
# - [ ]  Plot per-channel **bar plots** or **line plots** of alpha power by condition
# - [ ]  Plot **topoplots** (scalp maps) of:
#     - `state` slope per channel
#     - p-values (FDR-corrected or raw, with masking)
#     - t-values

# %%
import matplotlib.pyplot as plt
from utils.config import PLOTS_PATH
import os

# %% [markdown]
# ### **Correct for Multiple Comparisons**
#
# - [ ]  Across channels (e.g., for scalp maps), correct p-values using:
#     - **False Discovery Rate (FDR)**
#     - Or **cluster-based permutation test** if possible

# %% [markdown]
# ### **Filter Low-Effect Subjects**
#
# - [ ]  Compute within-subject effect sizes (e.g., Cohen’s *d*) between states
# - [ ]  Re-run the model excluding sessions with **d < 0.5**
# - [ ]  Compare results to check robustness
