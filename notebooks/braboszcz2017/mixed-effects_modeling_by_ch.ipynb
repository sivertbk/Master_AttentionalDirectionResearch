# %% [markdown]
# ### **Organize PSD Data**
#
# - [ ]  Ensure all power spectral data (PSD) is saved per **subject-session** in a consistent format:
#     - One file or object per subject-session
#     - Contains:
#         - EEG **channels**
#         - **Frequencies**
#         - Power per **epoch** or pre-averaged by condition
#     - Associated **metadata**:
#         - Subject ID
#         - Session ID
#         - Dataset name
#         - Cognitive **state label** (OT, MW)

# %%
from eeg_analyzer.dataset import Dataset
from utils.config import DATASETS

dataset_config = DATASETS['braboszcz2017']

dataset = Dataset(dataset_config)
dataset.load_subjects()

# %% [markdown]
# ### **Extract Alpha Power**
#
# - [ ]  For each subject-session
#     - Select **8–12 Hz** frequency band
#     - **Sum power across frequencies** per channel and epoch
# - [ ]  Result per epoch:
#
# ```python
# {
#     "subject_session": "001_1",
#     "subject_id": "001",
#     "session_id": "1",
#     "channel": "Pz",
#     "task": "SART",
#     "state": "MW",
#     "alpha_power": 3.45,
#     ...
# }
# ```

# %% [markdown]
# ### **Assign Numerical Condition Labels**
#
# For modeling the *ordinal direction* of alpha power:
#
# | State | Code |
# | --- | --- |
# | OT | 0 |
# | MW | 1 |
# | MED | 2 |
# - [ ]  For **Jin** and **Touryan**, you only use codes `0` and `1` (OT, MW)
# - [ ]  For **Braboszcz**, use codes `1` and `2` (MW, MED)

# %%
# Get all list of all epochs for all subject-session pairs as dict with these keys:
# 'subject_session', 'subject', 'session', 'channel', 'task', 'state', 'band_power'

epochs = dataset.to_long_band_power_list(freq_band=(8,12))  # Alpha band

estimated_length = dataset.estimate_long_band_power_length()

# %% [markdown]
# ### **Create Long-Form DataFrame per Dataset**
#
# For each dataset, prepare:
# | subject_session | subject_id | group | channel/ROI | state | alpha_power |
# | --- | --- | --- | --- | --- | --- |
# | 001_1 | 001 | NaN | Pz | 0 | 3.24 |
# | 001_1 | 001 | NaN | Pz | 1 | 3.88 |
# | 060_1 | 060 | vip | Pz | 1 | 5.12 |
# | 060_1 | 060 | vip | Pz | 2 | 6.00 |

# %%
# create a dataframe with the epochs
import pandas as pd
df_full = pd.DataFrame(epochs)
df_full.head()
# Out:
#   subject_session subject_id  session_id group  epoch_idx channel  \
# 0           025_1        025           1   ctr          0     Fp1
# 1           025_1        025           1   ctr          0     AF7
# 2           025_1        025           1   ctr          0     AF3
# 3           025_1        025           1   ctr          0      F1
# 4           025_1        025           1   ctr          0      F3
#
#   cortical_region hemisphere  task  state  band_power  is_bad
# 0      prefrontal       left  med2      0   23.498810   False
# 1      prefrontal       left  med2      0   19.521354   False
# 2      prefrontal       left  med2      0   27.098857   False
# 3         frontal       left  med2      0   37.130399   False
# 4         frontal       left  med2      0   29.661644   False

# %% [markdown]
# ## **Report the state balance**

# %%
state_counts = df_full['state'].value_counts()
state_counts = state_counts / state_counts.sum()
print(f"State balance: {state_counts.to_dict()}")
# Out:
# State balance: {0: 0.5088714761776096, 1: 0.49112852382239036}

# %% [markdown]
# ## **Make grouped DataFrames per channel**
#
# * [ ] Create a list of DataFrames for each its own channel.
# * [ ] Create a new column with the z-score within state.
# * [ ] Filter the data by removing all epochs with a z-score > 4.

# %%
# Filter the dataframe to only include rows where "group" == "vip"
df_full = df_full[df_full['group'] == 'ctr']

# Create a list of dataframes for each channel (keep the channel column)
df_channels = []
for channel in df_full['channel'].unique():
    df_channel = df_full[df_full['channel'] == channel].reset_index(drop=True)
    df_channels.append(df_channel)

# create a new column with z-scores within each state
# def z_score_within_state(df):
#     grouped = df.groupby(['subject_session', 'state'])
#     df['z_score'] = grouped['band_power'].transform(lambda x: (x - x.mean()) / x.std())
#     return df

# # apply the z-score function to each channel dataframe
# df_channels_z = []
# for df_channel in df_channels:
#     df_channel_z = z_score_within_state(df_channel)
#     df_channels_z.append(df_channel_z)

# # Remove all rows where z_score > 3
# for i in range(len(df_channels_z)):
#     df_channels_z[i] = df_channels_z[i][df_channels_z[i]['z_score'] <= 3]

# print(df_channels_z[0].head())

# %% [markdown]
# ### **Fit Mixed Effects Model per Channel**
#
# Do this **separately for each dataset** and for each channel (or ROI):
#
# ### ✅ Model formula:
#
# ```python
# alpha_power ~ state + (state | subject_session)
# ```
#
# This:
#
# - Estimates the effect of `state` (e.g., OT → MW or MW → MED)
# - Models per-subject variability in both baseline (intercept) and sensitivity (slope)

# %%
# Fit mixed effects model per channel
import statsmodels.formula.api as smf
from statsmodels.tools.sm_exceptions import ConvergenceWarning

results_per_channel = {}

for df_channel in df_channels:
    channel_name = df_channel['channel'].iloc[0] if 'channel' in df_channel else None
    # Fit the mixed effects model: alpha_power ~ state + (state | subject_session)
    # Use 'band_power' as the dependent variable
    # 'state' as fixed effect, random intercept and slope for 'subject_session'
    model = smf.mixedlm(
        "band_power ~ state",
        df_channel,
        groups="subject_session",
        re_formula="~state"
    )
    result = model.fit(method="lbfgs")
    results_per_channel[channel_name] = result

# Print summary for all channels
for channel in results_per_channel:
    if results_per_channel[channel].pvalues['state'] < 0.055:
        print(f"Results for channel: {channel}")
        print(results_per_channel[channel].summary())
# Out:
# Results for channel: P9
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  1262.2213
# Min. group size:        150         Log-Likelihood:         -34358.0641
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     55.254    6.466 8.545 0.000 42.581 67.928
# state                         12.155    5.896 2.062 0.039  0.600 23.710
# subject_session Var         1284.627    9.441
# subject_session x state Cov  136.510    6.107
# state Var                   1054.012    7.850
# =======================================================================
#
# Results for channel: TP8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      6859        Method:                 REML
# No. Groups:            31          Scale:                  551.3154
# Min. group size:       150         Log-Likelihood:         -31514.0221
# Max. group size:       270         Converged:              Yes
# Mean group size:       221.3
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    34.199    4.152 8.236 0.000 26.061 42.338
# state                         6.940    3.510 1.977 0.048  0.061 13.819
# subject_session Var         529.502    5.891
# subject_session x state Cov  70.091    3.548
# state Var                   371.616    4.201
# ======================================================================
#
# Results for channel: P8
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  2028.4404
# Min. group size:        150         Log-Likelihood:         -35984.0152
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     68.969    8.160 8.452 0.000 52.975 84.963
# state                         17.461    7.356 2.374 0.018  3.045 31.878
# subject_session Var         2045.877   11.865
# subject_session x state Cov -104.429    7.567
# state Var                   1639.516    9.639
# =======================================================================
#
# Results for channel: P10
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  2552.7082
# Min. group size:        150         Log-Likelihood:         -36765.6903
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     64.961    8.719 7.450 0.000 47.871 82.050
# state                         16.500    7.033 2.346 0.019  2.715 30.284
# subject_session Var         2333.697   12.069
# subject_session x state Cov  293.227    6.942
# state Var                   1485.839    7.853
# =======================================================================
#
# Results for channel: PO8
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      band_power
# No. Observations:      6859         Method:                  REML
# No. Groups:            31           Scale:                   7393.8827
# Min. group size:       150          Log-Likelihood:          -40419.7892
# Max. group size:       270          Converged:               Yes
# Mean group size:       221.3
# ------------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025  0.975]
# ------------------------------------------------------------------------
# Intercept                    110.235   14.364 7.674 0.000 82.081 138.388
# state                         31.963   15.933 2.006 0.045  0.735  63.191
# subject_session Var         6329.072   19.222
# subject_session x state Cov -157.366   15.065
# state Var                   7732.274   23.668
# ========================================================================

# %%
# get the model with the lowest AIC
best_model = None
best_aic = float('inf')
for channel, result in results_per_channel.items():
    print(result.rsquared)
    if result.aic < best_aic:
        best_aic = result.aic
        best_model = result

print(f"Best model: {best_model.model.formula} with AIC: {best_aic}")
# Save the results to a file
import pickle
with open('results_per_channel.pkl', 'wb') as f:
    pickle.dump(results_per_channel, f)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 5
#       3 best_aic = float('inf')
#       4 for channel, result in results_per_channel.items():
# ----> 5     print(result.rsquared)
#       6     if result.aic < best_aic:
#       7         best_aic = result.aic
#
# File c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      31 except AttributeError:
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#      36 how = self._wrap_attrs.get(attr)
#
# AttributeError: 'MixedLMResults' object has no attribute 'rsquared'

# %% [markdown]
# # Z-score normalize whitin-subject
# Z-score normalize whitin-subject across epochs and fit new models for easier interpretations

# %%
# create a new column with z-scores within each state
def z_score_within_state(df):
    grouped = df.groupby(['subject_session'])
    df['z_score'] = grouped['band_power'].transform(lambda x: (x - x.mean()) / x.std())
    return df

# apply the z-score function to each channel dataframe
df_channels_z = []
for df_channel in df_channels:
    df_channel_z = z_score_within_state(df_channel)
    df_channels_z.append(df_channel_z)

# %%
# Fit mixed effects model per channel with z-score insted of band_power

results_per_channel_z = {}

for df_channel in df_channels_z:
    channel_name = df_channel['channel'].iloc[0] if 'channel' in df_channel else None
    # Fit the mixed effects model: alpha_power ~ state + (state | subject_session)
    # Use 'band_power' as the dependent variable
    # 'state' as fixed effect, random intercept and slope for 'subject_session'
    model = smf.mixedlm(
        "z_score ~ state",
        df_channel,
        groups="subject_session",
        re_formula="~state"
    )
    result = model.fit(method="lbfgs")
    results_per_channel_z[channel_name] = result

# Print summary for all channels
for channel in results_per_channel_z:
    print(f"Results for channel: {channel}")
    print(results_per_channel_z[channel].summary())
# Out:
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 7.375181
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 103.788365
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 65.130978
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 97.262063
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 55.394138
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 58.153876
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 24.200744
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 74.745321
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 39.597218
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 78.150528
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 13.619988
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 93.977109
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 33.302073
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 64.578371
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 79.732754
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 89.980891
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 89.414758
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 94.612588
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 99.267337
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 11.594881
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 81.290621
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 18.197454
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 76.882360
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 72.244489
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 32.351889
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Results for channel: Fp1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9078
# Min. group size:        150         Log-Likelihood:         -9464.5058
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.055    0.067 -0.830 0.407 -0.187  0.076
# state                        0.124    0.132  0.937 0.349 -0.135  0.382
# subject_session Var          0.130    0.063
# subject_session x state Cov -0.259    0.125
# state Var                    0.522    0.237
# ======================================================================
#
# Results for channel: AF7
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9112
# Min. group size:        150         Log-Likelihood:         -9464.9392
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.051    0.055 -0.920 0.358 -0.159  0.057
# state                        0.111    0.107  1.038 0.299 -0.099  0.320
# subject_session Var          0.086    0.030
# subject_session x state Cov -0.171    0.051
# state Var                    0.337    0.096
# ======================================================================
#
# Results for channel: AF3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9099
# Min. group size:        150         Log-Likelihood:         -9460.7548
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.040    0.057 -0.706 0.480 -0.151  0.071
# state                        0.092    0.110  0.841 0.400 -0.123  0.308
# subject_session Var          0.092    0.033
# subject_session x state Cov -0.181    0.057
# state Var                    0.358    0.105
# ======================================================================
#
# Results for channel: F1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9135
# Min. group size:        150         Log-Likelihood:         -9473.9189
# Max. group size:        270         Converged:              No
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.004    0.057 -0.071 0.944 -0.116  0.108
# state                        0.015    0.108  0.138 0.890 -0.197  0.227
# subject_session Var          0.093    0.036
# subject_session x state Cov -0.180    0.058
# state Var                    0.347    0.102
# ======================================================================
#
# Results for channel: F3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8877
# Min. group size:        150         Log-Likelihood:         -9392.9753
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.003    0.090 -0.034 0.973 -0.179  0.173
# state                        0.006    0.180  0.034 0.973 -0.347  0.359
# subject_session Var          0.241
# subject_session x state Cov -0.487
# state Var                    0.988
# ======================================================================
#
# Results for channel: F5
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9105
# Min. group size:        150         Log-Likelihood:         -9465.5003
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.040    0.061 -0.660 0.509 -0.160  0.079
# state                        0.085    0.119  0.717 0.473 -0.148  0.318
# subject_session Var          0.108    0.075
# subject_session x state Cov -0.213    0.100
# state Var                    0.421    0.147
# ======================================================================
#
# Results for channel: F7
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9099
# Min. group size:        150         Log-Likelihood:         -9468.3994
# Max. group size:        270         Converged:              No
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.015    0.058 -0.262 0.793 -0.130  0.099
# state                        0.033    0.119  0.278 0.781 -0.200  0.266
# subject_session Var          0.098    0.032
# subject_session x state Cov -0.201    0.089
# state Var                    0.421    0.265
# ======================================================================
#
# Results for channel: FT7
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9107
# Min. group size:        150         Log-Likelihood:         -9469.6267
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.006    0.067 -0.092 0.927 -0.138  0.126
# state                        0.025    0.130  0.190 0.849 -0.230  0.280
# subject_session Var          0.132    0.056
# subject_session x state Cov -0.259    0.117
# state Var                    0.508    0.230
# ======================================================================
#
# Results for channel: FC5
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9146
# Min. group size:        150         Log-Likelihood:         -9477.3751
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.043    0.055 -0.788 0.431 -0.150  0.064
# state                        0.093    0.105  0.880 0.379 -0.114  0.299
# subject_session Var          0.084    0.031
# subject_session x state Cov -0.166    0.052
# state Var                    0.328    0.094
# ======================================================================
#
# Results for channel: FC3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8925
# Min. group size:        150         Log-Likelihood:         -9409.1173
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.052    0.086 -0.602 0.547 -0.221  0.117
# state                        0.111    0.170  0.652 0.515 -0.223  0.445
# subject_session Var          0.223
# subject_session x state Cov -0.444
# state Var                    0.882
# ======================================================================
#
# Results for channel: FC1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8916
# Min. group size:        150         Log-Likelihood:         -9401.0991
# Max. group size:        270         Converged:              No
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.003    0.072 -0.035 0.972 -0.143  0.138
# state                        0.013    0.141  0.096 0.924 -0.263  0.290
# subject_session Var          0.151    0.064
# subject_session x state Cov -0.300    0.129
# state Var                    0.599    0.239
# ======================================================================
#
# Results for channel: C1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8538
# Min. group size:        150         Log-Likelihood:         -9250.4006
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.085    0.071 -1.193 0.233 -0.224  0.055
# state                        0.188    0.138  1.367 0.172 -0.082  0.458
# subject_session Var          0.149    0.049
# subject_session x state Cov -0.292    0.091
# state Var                    0.572    0.173
# ======================================================================
#
# Results for channel: C3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9103
# Min. group size:        150         Log-Likelihood:         -9464.3061
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.019    0.058 -0.317 0.751 -0.133  0.096
# state                        0.056    0.117  0.483 0.629 -0.173  0.286
# subject_session Var          0.098    0.037
# subject_session x state Cov -0.199    0.070
# ...
# state Var                    0.392    0.167
# =====================================================================
#
# Results for channel: T8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9064
# Min. group size:        150         Log-Likelihood:         -9455.4124
# Max. group size:        270         Converged:              No
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.014    0.066 -0.217 0.828 -0.144  0.115
# state                        0.046    0.129  0.356 0.722 -0.207  0.299
# subject_session Var          0.128    0.051
# subject_session x state Cov -0.252    0.101
# state Var                    0.501    0.185
# ======================================================================
#
# Results for channel: TP8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9056
# Min. group size:        150         Log-Likelihood:         -9461.2595
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.035    0.065 -0.536 0.592 -0.161  0.092
# state                        0.080    0.139  0.572 0.567 -0.193  0.352
# subject_session Var          0.121    0.041
# subject_session x state Cov -0.262    0.052
# state Var                    0.583
# ======================================================================
#
# Results for channel: CP6
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9007
# Min. group size:        150         Log-Likelihood:         -9431.7833
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.013    0.067 -0.196 0.844 -0.145  0.119
# state                        0.036    0.132  0.271 0.786 -0.222  0.294
# subject_session Var          0.132    0.041
# subject_session x state Cov -0.263    0.099
# state Var                    0.521    0.211
# ======================================================================
#
# Results for channel: CP4
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9151
# Min. group size:        150         Log-Likelihood:         -9483.5903
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.007    0.064 -0.111 0.912 -0.132  0.118
# state                        0.033    0.121  0.275 0.783 -0.204  0.271
# subject_session Var          0.118
# subject_session x state Cov -0.227    0.072
# state Var                    0.440    0.171
# ======================================================================
#
# Results for channel: CP2
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.9036
# Min. group size:        150         Log-Likelihood:         -9439.6163
# Max. group size:        270         Converged:              No
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.016    0.062 -0.254 0.799 -0.136  0.105
# state                        0.055    0.118  0.467 0.640 -0.176  0.286
# subject_session Var          0.110    0.041
# subject_session x state Cov -0.213    0.071
# state Var                    0.414    0.131
# ======================================================================
#
# Results for channel: P2
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8862
# Min. group size:        150         Log-Likelihood:         -9375.2923
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.039    0.064 -0.607 0.544 -0.164  0.086
# state                        0.091    0.123  0.739 0.460 -0.150  0.331
# subject_session Var          0.118    0.052
# subject_session x state Cov -0.230    0.091
# state Var                    0.451    0.157
# ======================================================================
#
# Results for channel: P4
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8969
# Min. group size:        150         Log-Likelihood:         -9416.3579
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.087    0.059 -1.463 0.143 -0.203  0.029
# state                        0.190    0.115  1.645 0.100 -0.036  0.416
# subject_session Var          0.100    0.034
# subject_session x state Cov -0.198    0.061
# state Var                    0.396    0.129
# ======================================================================
#
# Results for channel: P6
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8870
# Min. group size:        150         Log-Likelihood:         -9383.2617
# Max. group size:        270         Converged:              No
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.068    0.071 -0.955 0.339 -0.207  0.071
# state                        0.139    0.141  0.990 0.322 -0.137  0.416
# subject_session Var          0.148    0.064
# subject_session x state Cov -0.297    0.124
# state Var                    0.599    0.231
# ======================================================================
#
# Results for channel: P8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8856
# Min. group size:        150         Log-Likelihood:         -9374.9273
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.113    0.069 -1.652 0.098 -0.248  0.021
# state                        0.231    0.135  1.708 0.088 -0.034  0.497
# subject_session Var          0.138    0.053
# subject_session x state Cov -0.276    0.115
# state Var                    0.552    0.236
# ======================================================================
#
# Results for channel: P10
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8824
# Min. group size:        150         Log-Likelihood:         -9367.3893
# Max. group size:        270         Converged:              No
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.073    0.078 -0.944 0.345 -0.226  0.079
# state                        0.156    0.153  1.024 0.306 -0.143  0.456
# subject_session Var          0.179    0.078
# subject_session x state Cov -0.356    0.171
# state Var                    0.708    0.364
# ======================================================================
#
# Results for channel: PO8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8723
# Min. group size:        150         Log-Likelihood:         -9326.3833
# Max. group size:        270         Converged:              No
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.089    0.075 -1.183 0.237 -0.236  0.058
# state                        0.174    0.149  1.172 0.241 -0.117  0.466
# subject_session Var          0.167    0.028
# subject_session x state Cov -0.334    0.115
# state Var                    0.670    0.274
# ======================================================================
#
# Results for channel: PO4
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8785
# Min. group size:        150         Log-Likelihood:         -9347.6365
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.089    0.068 -1.309 0.190 -0.223  0.044
# state                        0.183    0.136  1.346 0.178 -0.084  0.450
# subject_session Var          0.136    0.053
# subject_session x state Cov -0.276    0.130
# state Var                    0.559    0.323
# ======================================================================
#
# Results for channel: O2
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  0.8811
# Min. group size:        150         Log-Likelihood:         -9367.3973
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.078    0.095 -0.824 0.410 -0.265  0.108
# state                        0.159    0.184  0.864 0.388 -0.201  0.519
# subject_session Var          0.273
# subject_session x state Cov -0.530
# state Var                    1.030
# ======================================================================

# %%
# Fit mixed effects model per channel with z-score insted of band_power

results_per_channel_z = {}

for df_channel in df_channels_z:
    channel_name = df_channel['channel'].iloc[0] if 'channel' in df_channel else None
    # Fit the mixed effects model: alpha_power ~ state + (state | subject_session)
    # Use 'band_power' as the dependent variable
    # 'state' as fixed effect, random intercept and slope for 'subject_session'
    model = smf.mixedlm(
        "z_score ~ state",
        df_channel,
        groups="subject_session",
        re_formula="~1"
    )
    result = model.fit(method="lbfgs")
    results_per_channel_z[channel_name] = result

# Print summary for all channels
for channel in results_per_channel_z:
    print(f"Results for channel: {channel}")
    print(results_per_channel_z[channel].summary())
# Out:
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# ...
# No. Groups:                31             Scale:                     0.9957
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4313454.730 -0.000 1.000 -8454215.920 8454215.920
# state                0.022       0.024  0.903 0.367       -0.026       0.069
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: T8
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9950
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4311950.277 -0.000 1.000 -8451267.246 8451267.246
# state                0.057       0.024  2.367 0.018        0.010       0.105
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: TP8
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9942
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4310258.380 -0.000 1.000 -8447951.188 8447951.188
# state                0.080       0.024  3.315 0.001        0.033       0.128
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: CP6
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9953
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4312791.773 -0.000 1.000 -8452916.548 8452916.548
# state                0.041       0.024  1.710 0.087       -0.006       0.089
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: CP4
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9953
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4312641.849 -0.000 1.000 -8452622.702 8452622.702
# state                0.045       0.024  1.844 0.065       -0.003       0.092
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: CP2
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9947
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4311287.133 -0.000 1.000 -8449967.507 8449967.507
# state                0.067       0.024  2.777 0.005        0.020       0.115
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: P2
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9931
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4307994.013 -0.000 1.000 -8443513.112 8443513.112
# state                0.103       0.024  4.267 0.000        0.056       0.151
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: P4
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9860
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4292439.464 -0.000 1.000 -8413026.755 8413026.755
# state                0.199       0.024  8.254 0.000        0.152       0.246
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: P6
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9904
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4302140.013 -0.000 1.000 -8432039.482 8432039.482
# state                0.147       0.024  6.077 0.000        0.100       0.194
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: P8
#             Mixed Linear Model Regression Results
# =============================================================
# Model:               MixedLM  Dependent Variable:  z_score
# No. Observations:    6859     Method:              REML
# No. Groups:          31       Scale:               0.9955
# Min. group size:     150      Log-Likelihood:      -9722.4785
# Max. group size:     270      Converged:           Yes
# Mean group size:     221.3
# -------------------------------------------------------------
#                     Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           -0.000
# state                0.222    0.024 9.206 0.000  0.175  0.269
# subject_session Var  0.000
# =============================================================
#
# Results for channel: P10
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9898
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4300753.049 -0.000 1.000 -8429321.082 8429321.082
# state                0.155       0.024  6.433 0.000        0.108       0.203
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: PO8
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9876
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4296063.052 -0.000 1.000 -8420128.857 8420128.857
# state                0.181       0.024  7.513 0.000        0.134       0.229
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: PO4
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9868
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4294187.590 -0.000 1.000 -8416453.019 8416453.019
# state                0.191       0.024  7.905 0.000        0.143       0.238
# subject_session Var  0.000
# ============================================================================
#
# Results for channel: O2
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                     MixedLM        Dependent Variable:        z_score
# No. Observations:          6859           Method:                    REML
# No. Groups:                31             Scale:                     0.9896
# Min. group size:           150            Log-Likelihood:            inf
# Max. group size:           270            Converged:                 Yes
# Mean group size:           221.3
# ----------------------------------------------------------------------------
#                     Coef.    Std.Err.    z    P>|z|    [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept           -0.000 4300226.056 -0.000 1.000 -8428288.194 8428288.194
# state                0.159       0.024  6.563 0.000        0.111       0.206
# subject_session Var  0.000
# ============================================================================
# c:\Users\si_ve\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %% [markdown]
# ### **Store & Summarize Results**
#
# For each model/channel:
#
# - [ ]  Store:
#     - Fixed effect estimate for `state`
#     - p-value
#     - t-statistic (optional)
#     - Number of subjects included
# - [ ]  Save results to `.csv` or `.json`

# %% [markdown]
# ### **Visualize Results**
#
# - [ ]  Plot per-channel **bar plots** or **line plots** of alpha power by condition
# - [ ]  Plot **topoplots** (scalp maps) of:
#     - `state` slope per channel
#     - p-values (FDR-corrected or raw, with masking)
#     - t-values

# %%
import matplotlib.pyplot as plt
from utils.config import PLOTS_PATH
import os

# %% [markdown]
# ### **Correct for Multiple Comparisons**
#
# - [ ]  Across channels (e.g., for scalp maps), correct p-values using:
#     - **False Discovery Rate (FDR)**
#     - Or **cluster-based permutation test** if possible

# %% [markdown]
# ### **Filter Low-Effect Subjects**
#
# - [ ]  Compute within-subject effect sizes (e.g., Cohen’s *d*) between states
# - [ ]  Re-run the model excluding sessions with **d < 0.5**
# - [ ]  Compare results to check robustness
