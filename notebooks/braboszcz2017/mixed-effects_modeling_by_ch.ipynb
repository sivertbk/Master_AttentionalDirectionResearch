# %% [markdown]
# ### **Organize PSD Data**
#
# - [ ]  Ensure all power spectral data (PSD) is saved per **subject-session** in a consistent format:
#     - One file or object per subject-session
#     - Contains:
#         - EEG **channels**
#         - **Frequencies**
#         - Power per **epoch** or pre-averaged by condition
#     - Associated **metadata**:
#         - Subject ID
#         - Session ID
#         - Dataset name
#         - Cognitive **state label** (OT, MW)

# %%
from eeg_analyzer.dataset import Dataset
from utils.config import DATASETS

dataset_config = DATASETS['braboszcz2017']

dataset = Dataset(dataset_config)
dataset.load_subjects()

# %% [markdown]
# ### **Extract Alpha Power**
#
# - [ ]  For each subject-session
#     - Select **8–12 Hz** frequency band
#     - **Sum power across frequencies** per channel and epoch
# - [ ]  Result per epoch:
#
# ```python
# {
#     "subject_session": "001_1",
#     "subject_id": "001",
#     "session_id": "1",
#     "channel": "Pz",
#     "task": "SART",
#     "state": "MW",
#     "alpha_power": 3.45,
#     ...
# }
# ```

# %% [markdown]
# ### **Assign Numerical Condition Labels**
#
# For modeling the *ordinal direction* of alpha power:
#
# | State | Code |
# | --- | --- |
# | OT | 0 |
# | MW | 1 |
# | MED | 2 |
# - [ ]  For **Jin** and **Touryan**, you only use codes `0` and `1` (OT, MW)
# - [ ]  For **Braboszcz**, use codes `1` and `2` (MW, MED)

# %%
# Get all list of all epochs for all subject-session pairs as dict with these keys:
# 'subject_session', 'subject', 'session', 'channel', 'task', 'state', 'band_power'

epochs = dataset.to_long_band_power_list(freq_band=(8,12))  # Alpha band

estimated_length = dataset.estimate_long_band_power_length()

# %% [markdown]
# ### **Create Long-Form DataFrame per Dataset**
#
# For each dataset, prepare:
# | subject_session | subject_id | group | channel/ROI | state | alpha_power |
# | --- | --- | --- | --- | --- | --- |
# | 001_1 | 001 | NaN | Pz | 0 | 3.24 |
# | 001_1 | 001 | NaN | Pz | 1 | 3.88 |
# | 060_1 | 060 | vip | Pz | 1 | 5.12 |
# | 060_1 | 060 | vip | Pz | 2 | 6.00 |

# %%
# create a dataframe with the epochs
import pandas as pd
df_full = pd.DataFrame(epochs)
df_full.head()
# Out:
#   subject_session subject_id  session_id group  epoch_idx channel  \
# 0           025_1        025           1   ctr          0     Fp1
# 1           025_1        025           1   ctr          0     AF7
# 2           025_1        025           1   ctr          0     AF3
# 3           025_1        025           1   ctr          0      F1
# 4           025_1        025           1   ctr          0      F3
#
#   cortical_region hemisphere  task  state  band_power  is_bad
# 0      prefrontal       left  med2      0   23.498810   False
# 1      prefrontal       left  med2      0   19.521354   False
# 2      prefrontal       left  med2      0   27.098857   False
# 3         frontal       left  med2      0   37.130399   False
# 4         frontal       left  med2      0   29.661644   False

# %% [markdown]
# ## **Report the state balance**

# %%
state_counts = df_full['state'].value_counts()
state_counts = state_counts / state_counts.sum()
print(f"State balance: {state_counts.to_dict()}")
# Out:
# State balance: {0: 0.5088714761776096, 1: 0.49112852382239036}

# %% [markdown]
# ## **Make grouped DataFrames per channel**
#
# * [ ] Create a list of DataFrames for each its own channel.
# * [ ] Create a new column with the z-score within state.
# * [ ] Filter the data by removing all epochs with a z-score > 4.

# %%
# Filter the dataframe to only include rows where "group" == "vip"
df_full = df_full[df_full['group'] == 'ctr']

# Create a list of dataframes for each channel (keep the channel column)
df_channels = []
for channel in df_full['channel'].unique():
    df_channel = df_full[df_full['channel'] == channel].reset_index(drop=True)
    df_channels.append(df_channel)

# create a new column with z-scores within each state
# def z_score_within_state(df):
#     grouped = df.groupby(['subject_session', 'state'])
#     df['z_score'] = grouped['band_power'].transform(lambda x: (x - x.mean()) / x.std())
#     return df

# # apply the z-score function to each channel dataframe
# df_channels_z = []
# for df_channel in df_channels:
#     df_channel_z = z_score_within_state(df_channel)
#     df_channels_z.append(df_channel_z)

# # Remove all rows where z_score > 3
# for i in range(len(df_channels_z)):
#     df_channels_z[i] = df_channels_z[i][df_channels_z[i]['z_score'] <= 3]

# print(df_channels_z[0].head())

# %% [markdown]
# ### **Fit Mixed Effects Model per Channel**
#
# Do this **separately for each dataset** and for each channel (or ROI):
#
# ### ✅ Model formula:
#
# ```python
# alpha_power ~ state + (state | subject_session)
# ```
#
# This:
#
# - Estimates the effect of `state` (e.g., OT → MW or MW → MED)
# - Models per-subject variability in both baseline (intercept) and sensitivity (slope)

# %%
# Fit mixed effects model per channel
import statsmodels.formula.api as smf
from statsmodels.tools.sm_exceptions import ConvergenceWarning

results_per_channel = {}

for df_channel in df_channels:
    channel_name = df_channel['channel'].iloc[0] if 'channel' in df_channel else None
    # Fit the mixed effects model: alpha_power ~ state + (state | subject_session)
    # Use 'band_power' as the dependent variable
    # 'state' as fixed effect, random intercept and slope for 'subject_session'
    model = smf.mixedlm(
        "band_power ~ state",
        df_channel,
        groups="subject_session",
        re_formula="~state"
    )
    result = model.fit(method="lbfgs")
    results_per_channel[channel_name] = result

# Print summary for all channels
for channel in results_per_channel:
    if results_per_channel[channel].pvalues['state'] < 0.055:
        print(f"Results for channel: {channel}")
        print(results_per_channel[channel].summary())
# Out:
# Results for channel: P9
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  1262.2213
# Min. group size:        150         Log-Likelihood:         -34358.0641
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     55.254    6.466 8.545 0.000 42.581 67.928
# state                         12.155    5.896 2.062 0.039  0.600 23.710
# subject_session Var         1284.627    9.441
# subject_session x state Cov  136.510    6.107
# state Var                   1054.012    7.850
# =======================================================================
#
# Results for channel: TP8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM     Dependent Variable:     band_power
# No. Observations:      6859        Method:                 REML
# No. Groups:            31          Scale:                  551.3154
# Min. group size:       150         Log-Likelihood:         -31514.0221
# Max. group size:       270         Converged:              Yes
# Mean group size:       221.3
# ----------------------------------------------------------------------
#                              Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    34.199    4.152 8.236 0.000 26.061 42.338
# state                         6.940    3.510 1.977 0.048  0.061 13.819
# subject_session Var         529.502    5.891
# subject_session x state Cov  70.091    3.548
# state Var                   371.616    4.201
# ======================================================================
#
# Results for channel: P8
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  2028.4404
# Min. group size:        150         Log-Likelihood:         -35984.0152
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     68.969    8.160 8.452 0.000 52.975 84.963
# state                         17.461    7.356 2.374 0.018  3.045 31.878
# subject_session Var         2045.877   11.865
# subject_session x state Cov -104.429    7.567
# state Var                   1639.516    9.639
# =======================================================================
#
# Results for channel: P10
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:                  MixedLM     Dependent Variable:     band_power
# No. Observations:       6859        Method:                 REML
# No. Groups:             31          Scale:                  2552.7082
# Min. group size:        150         Log-Likelihood:         -36765.6903
# Max. group size:        270         Converged:              Yes
# Mean group size:        221.3
# -----------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                     64.961    8.719 7.450 0.000 47.871 82.050
# state                         16.500    7.033 2.346 0.019  2.715 30.284
# subject_session Var         2333.697   12.069
# subject_session x state Cov  293.227    6.942
# state Var                   1485.839    7.853
# =======================================================================
#
# Results for channel: PO8
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:                 MixedLM      Dependent Variable:      band_power
# No. Observations:      6859         Method:                  REML
# No. Groups:            31           Scale:                   7393.8827
# Min. group size:       150          Log-Likelihood:          -40419.7892
# Max. group size:       270          Converged:               Yes
# Mean group size:       221.3
# ------------------------------------------------------------------------
#                              Coef.   Std.Err.   z   P>|z| [0.025  0.975]
# ------------------------------------------------------------------------
# Intercept                    110.235   14.364 7.674 0.000 82.081 138.388
# state                         31.963   15.933 2.006 0.045  0.735  63.191
# subject_session Var         6329.072   19.222
# subject_session x state Cov -157.366   15.065
# state Var                   7732.274   23.668
# ========================================================================

# %% [markdown]
# # Z-score normalize whitin-subject
# Z-score normalize whitin-subject across epochs and fit new models for easier interpretations

# %%
# create a new column with z-scores within each state
def z_score_within_state(df):
    grouped = df.groupby(['subject_session'])
    df['z_score'] = grouped['band_power'].transform(lambda x: (x - x.mean()) / x.std())
    return df

# apply the z-score function to each channel dataframe
df_channels_z = []
for df_channel in df_channels:
    df_channel_z = z_score_within_state(df_channel)
    df_channels_z.append(df_channel_z)

# %%
# Fit mixed effects model per channel with z-score insted of band_power

results_per_channel_z = {}

for df_channel in df_channels_z:
    channel_name = df_channel['channel'].iloc[0] if 'channel' in df_channel else None
    # Fit the mixed effects model: alpha_power ~ state + (state | subject_session)
    # Use 'band_power' as the dependent variable
    # 'state' as fixed effect, random intercept and slope for 'subject_session'
    model = smf.mixedlm(
        "z_score ~ state",
        df_channel,
        groups="subject_session",
        re_formula="~state"
    )
    result = model.fit(method="lbfgs")
    results_per_channel_z[channel_name] = result

# Print summary for all channels
for channel in results_per_channel_z:
    print(f"Results for channel: {channel}")
    print(results_per_channel_z[channel].summary())
# Out:
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 36.186767
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 67.040521
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 51.730673
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 30.955827
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 28.162637
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 55.976690
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 24.582610
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 53.016617
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 66.263733
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 17.870560
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 4.278493
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 56.634065
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 35.824335
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 53.522331
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 66.914288
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 26.884349
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 44.854527
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 22.144475
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 41.816687
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 31.018150
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 24.145934
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 52.322899
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 58.641882
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 47.901229
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 6.340022
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 63.695775
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 60.792183
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 45.920756
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Results for channel: Fp1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9305
# Min. group size:        183         Log-Likelihood:         -5912.5995
# Max. group size:        262         Converged:              Yes
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.023    0.081 -0.288 0.774 -0.182  0.135
# state                        0.039    0.177  0.219 0.827 -0.307  0.385
# subject_session Var          0.116    0.137
# subject_session x state Cov -0.253    0.270
# state Var                    0.575    0.525
# ======================================================================
#
# Results for channel: AF7
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9290
# Min. group size:        183         Log-Likelihood:         -5896.6506
# Max. group size:        262         Converged:              Yes
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.031    0.064 -0.478 0.632 -0.156  0.095
# state                        0.056    0.126  0.445 0.656 -0.190  0.302
# subject_session Var          0.069    0.050
# subject_session x state Cov -0.140    0.075
# state Var                    0.283    0.116
# ======================================================================
#
# Results for channel: AF3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9300
# Min. group size:        183         Log-Likelihood:         -5900.3098
# Max. group size:        262         Converged:              Yes
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.010    0.069 -0.145 0.884 -0.145  0.125
# state                        0.008    0.134  0.059 0.953 -0.255  0.271
# subject_session Var          0.082
# subject_session x state Cov -0.163
# state Var                    0.326    0.131
# ======================================================================
#
# Results for channel: F1
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9408
# Min. group size:        183         Log-Likelihood:         -5923.0604
# Max. group size:        262         Converged:              Yes
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.010    0.061  0.164 0.870 -0.109  0.129
# state                       -0.025    0.121 -0.206 0.837 -0.263  0.213
# subject_session Var          0.062
# subject_session x state Cov -0.128    0.047
# state Var                    0.263    0.118
# ======================================================================
#
# Results for channel: F3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9334
# Min. group size:        183         Log-Likelihood:         -5913.6408
# Max. group size:        262         Converged:              Yes
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.010    0.076  0.126 0.900 -0.140  0.159
# state                       -0.031    0.161 -0.194 0.846 -0.346  0.284
# subject_session Var          0.103    0.098
# subject_session x state Cov -0.219    0.194
# state Var                    0.474    0.381
# ======================================================================
#
# Results for channel: F5
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9275
# Min. group size:        183         Log-Likelihood:         -5899.7829
# Max. group size:        262         Converged:              Yes
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.019    0.079  0.240 0.810 -0.136  0.174
# state                       -0.049    0.163 -0.302 0.763 -0.368  0.270
# subject_session Var          0.110    0.106
# subject_session x state Cov -0.231    0.214
# state Var                    0.486    0.427
# ======================================================================
#
# Results for channel: F7
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9337
# Min. group size:        183         Log-Likelihood:         -5911.0858
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.016    0.075  0.209 0.835 -0.131  0.162
# state                       -0.039    0.148 -0.265 0.791 -0.330  0.252
# subject_session Var          0.098    0.067
# subject_session x state Cov -0.198    0.143
# state Var                    0.402    0.301
# ======================================================================
#
# Results for channel: FT7
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9591
# Min. group size:        183         Log-Likelihood:         -5963.4375
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.064    0.050  1.293 0.196 -0.033  0.161
# state                       -0.136    0.107 -1.271 0.204 -0.347  0.074
# subject_session Var          0.038    0.024
# subject_session x state Cov -0.086    0.048
# state Var                    0.202    0.080
# ======================================================================
#
# Results for channel: FC5
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9273
# Min. group size:        183         Log-Likelihood:         -5899.7558
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.013    0.078  0.168 0.866 -0.140  0.167
# state                       -0.039    0.165 -0.238 0.812 -0.363  0.284
# subject_session Var          0.108    0.113
# subject_session x state Cov -0.232    0.237
# state Var                    0.501    0.492
# ======================================================================
#
# Results for channel: FC3
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9317
# Min. group size:        183         Log-Likelihood:         -5906.5537
# Max. group size:        262         Converged:              No
# ...
# state Var                    0.267    0.197
# ======================================================================
#
# Results for channel: T8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9656
# Min. group size:        183         Log-Likelihood:         -5973.6024
# Max. group size:        262         Converged:              Yes
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.018    0.047  0.373 0.709 -0.075  0.111
# state                       -0.051    0.095 -0.530 0.596 -0.238  0.136
# subject_session Var          0.034    0.014
# subject_session x state Cov -0.073    0.036
# state Var                    0.156    0.067
# ======================================================================
#
# Results for channel: TP8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9432
# Min. group size:        183         Log-Likelihood:         -5930.3652
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.040    0.066  0.600 0.548 -0.090  0.169
# state                       -0.095    0.134 -0.709 0.478 -0.359  0.168
# subject_session Var          0.075    0.057
# subject_session x state Cov -0.156    0.121
# state Var                    0.327    0.252
# ======================================================================
#
# Results for channel: CP6
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9488
# Min. group size:        183         Log-Likelihood:         -5938.6902
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.028    0.055 -0.510 0.610 -0.137  0.080
# state                        0.048    0.109  0.439 0.661 -0.165  0.260
# subject_session Var          0.049    0.095
# subject_session x state Cov -0.101    0.119
# state Var                    0.206    0.106
# ======================================================================
#
# Results for channel: CP4
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9503
# Min. group size:        183         Log-Likelihood:         -5939.9751
# Max. group size:        262         Converged:              Yes
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.102    0.051 -2.004 0.045 -0.202 -0.002
# state                        0.198    0.098  2.020 0.043  0.006  0.389
# subject_session Var          0.041
# subject_session x state Cov -0.082    0.006
# state Var                    0.165    0.072
# ======================================================================
#
# Results for channel: CP2
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9597
# Min. group size:        183         Log-Likelihood:         -5962.7814
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.070    0.052 -1.368 0.171 -0.171  0.031
# state                        0.129    0.104  1.242 0.214 -0.075  0.333
# subject_session Var          0.042    0.024
# subject_session x state Cov -0.088    0.050
# state Var                    0.188    0.092
# ======================================================================
#
# Results for channel: P2
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9398
# Min. group size:        183         Log-Likelihood:         -5923.1962
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.014    0.060 -0.232 0.817 -0.132  0.104
# state                        0.018    0.122  0.146 0.884 -0.222  0.257
# subject_session Var          0.060    0.022
# subject_session x state Cov -0.125    0.055
# state Var                    0.267    0.064
# ======================================================================
#
# Results for channel: P4
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9279
# Min. group size:        183         Log-Likelihood:         -5897.9458
# Max. group size:        262         Converged:              Yes
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                   -0.018    0.067 -0.269 0.788 -0.149  0.113
# state                        0.027    0.148  0.182 0.855 -0.263  0.317
# subject_session Var          0.076
# subject_session x state Cov -0.174
# state Var                    0.399
# ======================================================================
#
# Results for channel: P6
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9226
# Min. group size:        183         Log-Likelihood:         -5887.8637
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.011    0.081  0.136 0.892 -0.147  0.169
# state                       -0.036    0.165 -0.219 0.826 -0.359  0.287
# subject_session Var          0.115    0.092
# subject_session x state Cov -0.239    0.183
# state Var                    0.499    0.356
# ======================================================================
#
# Results for channel: P8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9307
# Min. group size:        183         Log-Likelihood:         -5900.0473
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.063    0.063  0.990 0.322 -0.061  0.186
# state                       -0.138    0.122 -1.125 0.260 -0.378  0.102
# subject_session Var          0.064    0.121
# subject_session x state Cov -0.130    0.137
# state Var                    0.266    0.110
# ======================================================================
#
# Results for channel: P10
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9041
# Min. group size:        183         Log-Likelihood:         -5848.0968
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.134    0.084  1.583 0.114 -0.032  0.299
# state                       -0.275    0.175 -1.567 0.117 -0.619  0.069
# subject_session Var          0.127    0.127
# subject_session x state Cov -0.267    0.248
# state Var                    0.568    0.478
# ======================================================================
#
# Results for channel: PO8
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9360
# Min. group size:        183         Log-Likelihood:         -5918.2761
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.069    0.069  0.993 0.321 -0.067  0.204
# state                       -0.145    0.143 -1.017 0.309 -0.425  0.135
# subject_session Var          0.082    0.066
# subject_session x state Cov -0.173    0.135
# state Var                    0.371    0.268
# ======================================================================
#
# Results for channel: PO4
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9178
# Min. group size:        183         Log-Likelihood:         -5877.6566
# Max. group size:        262         Converged:              No
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.053    0.083  0.644 0.520 -0.109  0.216
# state                       -0.120    0.172 -0.697 0.486 -0.458  0.217
# subject_session Var          0.123    0.132
# subject_session x state Cov -0.259    0.267
# state Var                    0.547    0.539
# ======================================================================
#
# Results for channel: O2
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                  MixedLM     Dependent Variable:     z_score
# No. Observations:       4244        Method:                 REML
# No. Groups:             19          Scale:                  0.9305
# Min. group size:        183         Log-Likelihood:         -5903.4923
# Max. group size:        262         Converged:              Yes
# Mean group size:        223.4
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.076    0.067  1.134 0.257 -0.056  0.209
# state                       -0.162    0.137 -1.180 0.238 -0.431  0.107
# subject_session Var          0.078    0.045
# subject_session x state Cov -0.162    0.094
# state Var                    0.342    0.183
# ======================================================================

# %%
# Fit mixed effects model per channel with z-score insted of band_power

results_per_channel_z = {}

for df_channel in df_channels_z:
    channel_name = df_channel['channel'].iloc[0] if 'channel' in df_channel else None
    # Fit the mixed effects model: alpha_power ~ state + (state | subject_session)
    # Use 'band_power' as the dependent variable
    # 'state' as fixed effect, random intercept and slope for 'subject_session'
    model = smf.mixedlm(
        "z_score ~ state",
        df_channel,
        groups="subject_session",
        re_formula="~1"
    )
    result = model.fit(method="lbfgs")
    results_per_channel_z[channel_name] = result

# Print summary for all channels
for channel in results_per_channel_z:
    print(f"Results for channel: {channel}")
    print(results_per_channel_z[channel].summary())
# Out:
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2054: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2245: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# ...
# state               0.015      0.031 0.501 0.616      -0.045      0.076
# subject_session Var 0.000
# =======================================================================
#
# Results for channel: C6
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9935
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.035 372556.059 -0.000 1.000 -730196.492 730196.422
# state                0.101      0.031  3.287 0.001       0.041      0.161
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: T8
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9953
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept            0.011 372895.793  0.000 1.000 -730862.313 730862.334
# state               -0.054      0.031 -1.749 0.080      -0.114      0.006
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: TP8
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9933
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept            0.032 372520.239  0.000 1.000 -730126.220 730126.284
# state               -0.105      0.031 -3.409 0.001      -0.165     -0.045
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: CP6
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9955
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.009 372943.756 -0.000 1.000 -730956.340 730956.321
# state                0.043      0.031  1.403 0.161      -0.017      0.104
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: CP4
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9858
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.048 371114.236 -0.000 1.000 -727370.584 727370.489
# state                0.203      0.031  6.627 0.000       0.143      0.263
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: CP2
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9917
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.028 372218.041 -0.000 1.000 -729533.983 729533.927
# state                0.132      0.031  4.305 0.000       0.072      0.192
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: P2
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9959
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.013 373015.282 -0.000 1.000 -731096.532 731096.505
# state                0.018      0.031  0.584 0.559      -0.042      0.078
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: P4
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9959
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept           -0.014 373009.191 -0.000 1.000 -731084.594 731084.567
# state                0.021      0.031  0.692 0.489      -0.039      0.082
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: P6
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9954
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept            0.025 372910.458  0.000 1.000 -730891.043 730891.093
# state               -0.051      0.031 -1.651 0.099      -0.111      0.010
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: P8
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9898
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept            0.033 371876.906  0.000 1.000 -728865.311 728865.376
# state               -0.158      0.031 -5.134 0.000      -0.218     -0.097
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: P10
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:              MixedLM   Dependent Variable:   z_score
# No. Observations:   4244      Method:               REML
# No. Groups:         19        Scale:                0.9849
# Min. group size:    183       Log-Likelihood:       -5994.4777
# Max. group size:    262       Converged:            Yes
# Mean group size:    223.4
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept            0.045
# state               -0.294    0.030 -9.657 0.000 -0.354 -0.234
# subject_session Var  0.000
# ==============================================================
#
# Results for channel: PO8
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9899
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept            0.028 371881.937  0.000 1.000 -728875.175 728875.231
# state               -0.157      0.031 -5.122 0.000      -0.217     -0.097
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: PO4
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9920
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept            0.033 372276.355  0.000 1.000 -729648.215 729648.281
# state               -0.127      0.031 -4.147 0.000      -0.188     -0.067
# subject_session Var  0.000
# =========================================================================
#
# Results for channel: O2
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                    MixedLM       Dependent Variable:       z_score
# No. Observations:         4244          Method:                   REML
# No. Groups:               19            Scale:                    0.9892
# Min. group size:          183           Log-Likelihood:           inf
# Max. group size:          262           Converged:                Yes
# Mean group size:          223.4
# -------------------------------------------------------------------------
#                     Coef.   Std.Err.    z    P>|z|    [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept            0.055 371750.300  0.000 1.000 -728617.145 728617.255
# state               -0.166      0.031 -5.409 0.000      -0.226     -0.106
# subject_session Var  0.000
# =========================================================================
# /home/sivert/anaconda3/envs/mne-env/lib/python3.9/site-packages/statsmodels/regression/mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %% [markdown]
# ### **Store & Summarize Results**
#
# For each model/channel:
#
# - [ ]  Store:
#     - Fixed effect estimate for `state`
#     - p-value
#     - t-statistic (optional)
#     - Number of subjects included
# - [ ]  Save results to `.csv` or `.json`

# %% [markdown]
# ### **Visualize Results**
#
# - [ ]  Plot per-channel **bar plots** or **line plots** of alpha power by condition
# - [ ]  Plot **topoplots** (scalp maps) of:
#     - `state` slope per channel
#     - p-values (FDR-corrected or raw, with masking)
#     - t-values

# %%
import matplotlib.pyplot as plt
from utils.config import PLOTS_PATH
import os

# %% [markdown]
# ### **Correct for Multiple Comparisons**
#
# - [ ]  Across channels (e.g., for scalp maps), correct p-values using:
#     - **False Discovery Rate (FDR)**
#     - Or **cluster-based permutation test** if possible

# %% [markdown]
# ### **Filter Low-Effect Subjects**
#
# - [ ]  Compute within-subject effect sizes (e.g., Cohen’s *d*) between states
# - [ ]  Re-run the model excluding sessions with **d < 0.5**
# - [ ]  Compare results to check robustness
